# %% [markdown]
# # Modify Nodes in an NDEx Network Based on a TSV File

# %% [markdown]
# In this notebook, you will modify a network from NDEx that shows the interactions between the NCI ITCR projects.
#
# This version is missing some node attributes and needs corrections to the organization of their attributes.
#
# The network will be updated based on a TSV file where each row has information about one of the ITCR projects.
#
# The workflow:
#  * Load the TSV file as a Pandas Dataframe
#  * Create an NiceCX network from the network on NDEx
#  * For each row in the Dataframe:
#   * Identify the corresponding node (skip if there is no such node)
#   * Add attributes to the node based on the following columns:
#    * “Category”
#    * “Tool URL”
#    * “Code Repo”
#    * “Project Info”
#   * Set the "Tool Description" attribute of the node to the value of the "Body" column
#   * Set the node name to be the value of the "Title" column
#   * Set the "label" attribute to the value of the "Tool Acronym" when available, otherwise use the value of the "Title" column.
#  * Save the network to your account on NDEx
#
# The final network should still have 36 nodes/81 edges but provide extra info and link out to external resource

# %% [markdown]
# First, import the ndex2 Python client, Pandas, and itertools

# %%
import ndex2
import pandas as pd
import itertools

# %% [markdown]
# Next, set a variable to hold the UUID of the network we want to modify

# %%
my_network_uuid = '04c0a7e8-af92-11e7-94d3-0ac135e8bacf'

# %% [markdown]
# Set variables to hold your account and password

# %%
my_server = 'public.ndexbio.org'
my_account = "drh"
my_password = "drh"

# %% [markdown]
# Create a NiceCX network from the ITCR network..

# %%
print("downloading network and buiding NiceCX...")
itcr_network = ndex2.create_nice_cx_from_server(server=my_server, uuid=my_network_uuid)
#my_network = ndex2.create_nice_cx_from_server(server='public.ndexbio.org', uuid=my_network_uuid, account=my_account, password = my_password)
print("done")
print(itcr_network.get_summary())
# Out:
# downloading network and buiding NiceCX...
# done
# Name: ITCR Connectivity Map
# Nodes: 36
# Edges: 81
# Node Attributes: 0
# Edge Attributes: 241

# %% [markdown]
# Load the TSV to a Datframe

# %%
tsv_path = '../resources/itcr-conn-map-v2.0_nodes.txt'
node_data = pd.read_csv(tsv_path, sep="\t")
node_data
# Out:
#                                                 Title Tool Acronym  \
# 0                                           3D Slicer          NaN
# 1   Allele-Specific Alternative mRNA processing (A...        ASARP
# 2   Apache Clinical Text and Knowledge Extraction ...       cTAKES
# 3                                        Bioconductor          NaN
# 4                Cancer and Phenomics Toolkit (CaPTK)        CaPTK
# 5                 Cancer Slide Digital Archive (CDSA)         CDSA
# 6   Cancer-Related Analysis of Variants Toolkit (C...       CRAVAT
# 7                                            Cistrome          NaN
# 8   Clinical Interpretation of Variants in Cancer ...        CIViC
# 9                    Cores Of Recurrent Events (CORE)         CORE
# 10                                           D2Refine          NaN
# 11                              DICOM ToolKit (DCMTK)        DCMTK
# 12  Enhancer Linking by Methylation/Expression Rel...        ELMER
# 13                                         Feature DB          NaN
# 14                                Galaxy-P multiOmics     Galaxy-P
# 15                                        GenePattern          NaN
# 16  Genome-Independent Identification of RNA Editi...       GIREMI
# 17                  Integrative Genomics Viewer (IGV)          IGV
# 18                                           LSTM-CRF          NaN
# 19                     Methylation Integration (Mint)         Mint
# 20     Modified UMS, Modified SemRep and SemMedDB-UTH          NaN
# 21  Mutated Positions in Annotated Structures (MuPIT)        MuPIT
# 22                   The Network Data Exchange (NDEx)         NDEx
# 23                Next Generation Clustered Heat Maps          NaN
# 24                                         OmniSearch          NaN
# 25                Ontology for MIcroRNA Target (OMIT)         OMIT
# 26                     LesionTracker Web Image Viewer          NaN
# 27                                             owl-qa          NaN
# 28                                             P-Mart          NaN
# 29                        Personalized Cancer Therapy          NaN
# 30                                           PhenStat          NaN
# 31           Quantitative Imaging In Pathology (QUIP)         QUIP
# 32                                       RADIOMICS.io          NaN
# 33                                   Region Templates          NaN
# 34                                          SampleMap          NaN
# 35      Pathology Imaging Informatics Platform (PIIP)         PIIP
# 36                                          FHIR ShEx          NaN
# 37                                         SlicerDMRI          NaN
# 38          Text Information Extraction System (TIES)         TIES
# 39  The Laboratory for Individualized Breast Radio...        LIBRA
# 40                                            Trinity          NaN
# 41                                          UCSC Xena          NaN
# 42                                             WebMeV          NaN
# 43                                               XNAT          NaN
# 44    Cloud-based Image Biomarker Platform  (C-BIBOP)      C-BIBOP
# 45                                         ivyGlimpse          NaN
# 46                          The Cancer Proteome Atlas          NaN
# 47                                           DINC 2.0          NaN
# 48                                           AMARETTO          NaN
# 49              dcmqi: DICOM for Quantitative Imaging          NaN
# 50     Tools for Quantitative Analysis of PET Imaging          NaN
# 51                                       CLAMP-Cancer          NaN
# 52  Tumor Heterogenity Research Interactive Visual...       THRIVE
# 53                                        PETCT-CoSeg          NaN
# 54                   Single Cell Genome Viewer (SCGV)         SCGV
# 55                                            BioMuta          NaN
# 56                 The Cancer Imaging Archive (TCIA)          TCIA
# 57                    cBioPortal for Cancer Genomics    cBioPortal
# 58            Patient-Derived Xenograft (PDX) Finder    PDX Finder
# 59              The BioMedical Evidence Graph (BMEG)          BMEG
#
#                                                  Body  \
# 0   3D Slicer is the free open source software for...
# 1   A software pipeline for prediction of allele-s...
# 2   The tool extracts deep phenotypic information ...
# 3   Bioconductor provides tools for the analysis a...
# 4   CaPTk is a tool that facilitates translation o...
# 5   The CDSA is a web-based platform to support th...
# 6   CRAVAT is an easy to use web-based tool for an...
# 7   Curated and processed human/mouse ChIP/DNase-s...
# 8   CIViC is an open access, open source, communit...
# 9   CORE is a statistically supported computationa...
# 10  D2Refine is an integrated platform that enable...
# 11         DCMTK is an open source DICOM toolkit.\r\n
# 12  R tool for analysis of DNA methylation and exp...
# 13  The backend database to manage segmentation re...
# 14  A unified platform for integrative genomic-pro...
# 15  GenePattern is a genomic analysis platform tha...
# 16  Identification of single-nucleotide variants i...
# 17  The Integrative Genomics Viewer (IGV) is a hig...
# 18  LSTM-CRF uses Natural Language Processing meth...
# 19  A comprehensive software pipeline and set of G...
# 20  Modified UMLS, modified SemRep and SemMedDB-UT...
# 21  MuPIT provides 3D visualization of mutation cl...
# 22  NDEx is an online commons where scientists can...
# 23  Next-Generation (Clustered) Heat Maps are inte...
# 24  OmniSearch is a semantic search software based...
# 25  OMIT is a domain ontology specifically designe...
# 26  Extensible open-source zero-footprint web imag...
# 27  owl-qa is an OWL-based QA tool for cancer stud...
# 28  Web-based software platform to enable analysis...
# 29  Curated website cataloguing clinically actiona...
# 30  PhenStat is a freely available R package that ...
# 31  This site hosts web accessible applications, t...
# 32  RADIOMICS.io is a open source platform for inf...
# 33  A suite of libraries and runtime to support im...
# 34  Projects samples into a GoogleMap explorer to ...
# 35  Freely downloadable pathology viewer which sup...
# 36  ShEx is a QA tool based on the Shape Expressio...
# 37  Diffusion magnetic resonance imaging for neuro...
# 38  TIES is a service based software system for ac...
# 39  LIBRA is a fully-automatic breast density esti...
# 40  Trinity Cancer Transcriptome Analysis Toolkit ...
# 41  UCSC Xena securely analyzes and visualizes you...
# 42  Web MeV (Multiple-experiment Viewer) is a web/...
# 43  XNAT is an open source imaging informatics pla...
# 44  C-BIBOP is a cloud based platform for medical ...
# 45  Bioconductor-based interface to Ivy-GAP (gliob...
# 46  The Cancer Proteome Atals is a comprehensive b...
# 47  DINC 2.0 is a parallelized meta-docking method...
# 48  AMARETTO for multiOmics data fusion and reform...
# 49  dcmqi is a free, open source library that impl...
# 50  A collection of extensions for 3D Slicer to en...
# 51  A tool to quickly build customized natural lan...
# 52  A platform for quantitative evaluation of intr...
# 53  A PET-CT co-segmentation tool for tumor deline...
# 54  Graphics user interface for single-cell genomi...
# 55                Cancer associated gene mutation\r\n
# 56  TCIA is NCI’s repository for publicly shared c...
# 57  The cBioPortal for Cancer Genomics provides vi...
# 58  PDX Finder, currently in the prototyping phase...
# 59  The BMEG is a Cancer Data integration Platform...
#
#                    Category  \
# 0                   Imaging
# 1                     omics
# 2                  Clinical
# 3                     Omics
# 4                   Imaging
# 5                   Imaging
# 6                     Omics
# 7                     Omics
# 8           Omics, Clinical
# 9                     Omics
# 10           Data Standards
# 11  Imaging, Data Standards
# 12                    Omics
# 13                  Imaging
# 14                    Omics
# 15                    Omics
# 16                    Omics
# 17                    Omics
# 18                    Omics
# 19                    Omics
# 20          Clinical, Omics
# 21                    Omics
# 22          Network Biology
# 23                    Omics
# 24           Data Standards
# 25           Data Standards
# 26                  Imaging
# 27           Data Standards
# 28                    Omics
# 29          Clinical, Omics
# 30                    Omics
# 31                  Imaging
# 32                  Imaging
# 33                  Imaging
# 34                    Omics
# 35                  Imaging
# 36           Data Standards
# 37                  Imaging
# 38                 Clinical
# 39                  Imaging
# 40                    Omics
# 41                    Omics
# 42                    Omics
# 43                  Imaging
# 44                  Imaging
# 45           Imaging, Omics
# 46                    Omics
# 47                    Omics
# 48                    Omics
# 49  Data Standards, Imaging
# 50                  Imaging
# 51                 Clinical
# 52                  Imaging
# 53                  Imaging
# 54                    Omics
# 55                    Omics
# 56                  Imaging
# 57                    Omics
# 58                    Omics
# 59                    Omics
#
#                                              Tool URL  \
# 0                              https://www.slicer.org
# 1   https://www.ibp.ucla.edu/research/xiao/Softwar...
# 2                            http://ctakes.apache.org
# 3                        https://www.bioconductor.org
# 4                     http://captk.projects.nitrc.org
# 5               http://cancer.digitalslidearchive.net
# 6                        http://www.cravat.us/CRAVAT/
# 7   http://cistrome.org/Cistrome/Cistrome_Project....
# 8                 https://civic.genome.wustl.edu/home
# 9                                                 NaN
# 10          https://github.com/caCDE-QA/D2Refine/wiki
# 11                 http://dicom.offis.de/dcmtk.php.en
# 12  http://bioconductor.org/packages/release/bioc/...
# 13                                                NaN
# 14                                 http://galaxyp.org
# 15  http://software.broadinstitute.org/cancer/soft...
# 16                                                NaN
# 17                                 http://www.igv.org
# 18                                                NaN
# 19                  https://github.com/sartorlab/mint
# 20   https://skr3.nlm.nih.gov/SemMedDB/index_uth.html
# 21        http://mupit.icm.jhu.edu/MuPIT_Interactive/
# 22                            http://www.ndexbio.org/
# 23  http://bioinformatics.mdanderson.org/TCGA/NGCH...
# 24         http://omnisearch.soc.southalabama.edu/ui/
# 25  http://omnisearch.soc.southalabama.edu/w/index...
# 26                      http://lesiontracker.ohif.org
# 27                 https://github.com/caCDE-QA/owl-qa
# 28              https://pmart.labworks.org/index.html
# 29                      https://pct.mdanderson.org/#/
# 30                                                NaN
# 31                     http://quip.bmi.stonybrook.edu
# 32                           https://www.radiomics.io
# 33                                                NaN
# 34                          https://tumormap.ucsc.edu
# 35                                 http://pathiip.org
# 36                   https://github.com/caCDE-QA/ShEX
# 37                             http://dmri.slicer.org
# 38                          http://ties.dbmi.pitt.edu
# 39          https://www.med.upenn.edu/sbia/libra.html
# 40  https://github.com/trinityrnaseq/trinityrnaseq...
# 41                               http://xena.ucsc.edu
# 42                       http://mev.tm4.org/#/welcome
# 43                                http://www.xnat.org
# 44                            http://cbibop.github.io
# 45            https://vjcitn.shinyapps.io/ivyglimpse/
# 46                              http://tcpaportal.org
# 47                         http://dinc.kavrakilab.org
# 48  https://personal.broadinstitute.org/npochet/re...
# 49                                                NaN
# 50                          http://qin.iibi.uiowa.edu
# 51                    http://clamp.uth.edu/cancer.php
# 52                       http://www.csb.pitt.edu/ith/
# 53                                                NaN
# 54                                                NaN
# 55          https://hive.biochemistry.gwu.edu/biomuta
# 56                http://www.cancerimagingarchive.net
# 57                          http://www.cbioportal.org
# 58                           http://www.pdxfinder.org
# 59                                     http://bmeg.io
#
#                                             Code Repo  \
# 0                           https://github.com/Slicer
# 1                  https://github.com/cyruschan/ASARP
# 2              http://ctakes.apache.org/downloads.cgi
# 3      http://bioconductor.org/developers/how-to/git/
# 4                                                 NaN
# 5                                                 NaN
# 6                https://github.com/KarchinLab/CRAVAT
# 7                                                 NaN
# 8                      https://github.com/griffithlab
# 9     http://cran.us.r-project.org/web/packages/CORE/
# 10               https://github.com/caCDE-QA/D2Refine
# 11                               http://git.dcmtk.org
# 12                  https://github.com/lijingya/ELMER
# 13     https://github.com/SBU-BMI/pathomics_featuredb
# 14  https://github.com/galaxyproteomics/tools-galaxyp
# 15  https://github.com/genepattern/genepattern-server
# 16                 https://github.com/zhqingit/giremi
# 17                         https://github.com/igvteam
# 18      https://github.com/abhyudaynj/LSTM-CRF-models
# 19                  https://github.com/sartorlab/mint
# 20                                                NaN
# 21                                                NaN
# 22                         https://github.com/ndexbio
# 23                                                NaN
# 24                 https://github.com/OmniSearch/ncro
# 25                 https://github.com/OmniSearch/ncro
# 26                            https://github.com/OHIF
# 27                 https://github.com/caCDE-QA/owl-qa
# 28           https://hub.docker.com/r/pnnl/pmart-web/
# 29                                                NaN
# 30  https://bioconductor.org/packages/release/bioc...
# 31                  https://github.com/SBU-BMI/nscale
# 32                       https://github.com/Radiomics
# 33        https://github.com/SBU-BMI/region-templates
# 34                                                NaN
# 35                                                NaN
# 36                   https://github.com/caCDE-QA/ShEX
# 37                      https://github.com/SlicerDMRI
# 38           https://sourceforge.net/projects/caties/
# 39                                                NaN
# 40     https://github.com/trinityrnaseq/trinityrnaseq
# 41                       https://github.com/ucscXena/
# 42                   https://github.com/dfci-cccb/mev
# 43             https://bitbucket.org/xnatdev/xnat-web
# 44                                                NaN
# 45                 https://github.com/vjcitn/ivygapSE
# 46                                                NaN
# 47                   http://dinc.kavrakilab.org/help/
# 48  https://bitbucket.org/gevaertlab/pancanceramar...
# 49                     https://github.com/qiicr/dcmqi
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53  https://github.com/IOWA-PETCT-COSEG/PETCT_Slic...
# 54                https://github.com/KrasnitzLab/SCGV
# 55   https://hive.biochemistry.gwu.edu/biomuta/readme
# 56                                                NaN
# 57                     https://github.com/cBioPortal/
# 58             https://github.com/PDXFinder/pdxfinder
# 59                            https://github.com/bmeg
#
#                                          Project Info
# 0   https://projectreporter.nih.gov/project_info_d...
# 1   https://projectreporter.nih.gov/project_info_d...
# 2   https://projectreporter.nih.gov/project_info_d...
# 3   https://projectreporter.nih.gov/project_info_d...
# 4   https://projectreporter.nih.gov/project_info_d...
# 5   https://projectreporter.nih.gov/project_info_d...
# 6   https://projectreporter.nih.gov/project_info_d...
# 7   https://projectreporter.nih.gov/project_info_d...
# 8   https://projectreporter.nih.gov/project_info_d...
# 9   https://projectreporter.nih.gov/project_info_d...
# 10  https://projectreporter.nih.gov/project_info_d...
# 11  https://projectreporter.nih.gov/project_info_d...
# 12  https://projectreporter.nih.gov/project_info_d...
# 13  https://projectreporter.nih.gov/project_info_d...
# 14  https://projectreporter.nih.gov/project_info_d...
# 15  https://projectreporter.nih.gov/project_info_d...
# 16  https://projectreporter.nih.gov/project_info_d...
# 17  https://projectreporter.nih.gov/project_info_d...
# 18  https://projectreporter.nih.gov/project_info_d...
# 19  https://projectreporter.nih.gov/project_info_d...
# 20  https://projectreporter.nih.gov/project_info_d...
# 21  https://projectreporter.nih.gov/project_info_d...
# 22  https://projectreporter.nih.gov/project_info_d...
# 23  https://projectreporter.nih.gov/project_info_d...
# 24  https://projectreporter.nih.gov/project_info_d...
# 25  https://projectreporter.nih.gov/project_info_d...
# 26  https://projectreporter.nih.gov/project_info_d...
# 27  https://projectreporter.nih.gov/project_info_d...
# 28  https://projectreporter.nih.gov/project_info_d...
# 29  https://projectreporter.nih.gov/project_info_d...
# 30  https://projectreporter.nih.gov/project_info_d...
# 31  https://projectreporter.nih.gov/project_info_d...
# 32  https://projectreporter.nih.gov/project_info_d...
# 33  https://projectreporter.nih.gov/project_info_d...
# 34  https://projectreporter.nih.gov/project_info_d...
# 35  https://projectreporter.nih.gov/project_info_d...
# 36  https://projectreporter.nih.gov/project_info_d...
# 37  https://projectreporter.nih.gov/project_info_d...
# 38  https://projectreporter.nih.gov/project_info_d...
# 39  https://projectreporter.nih.gov/project_info_d...
# 40  https://projectreporter.nih.gov/project_info_d...
# 41  https://projectreporter.nih.gov/project_info_d...
# 42  https://projectreporter.nih.gov/project_info_d...
# 43  https://projectreporter.nih.gov/project_info_d...
# 44  https://projectreporter.nih.gov/project_info_d...
# 45        https://www.youtube.com/watch?v=4qJaodLEI5o
# 46  https://projectreporter.nih.gov/project_info_d...
# 47                                                NaN
# 48                                                NaN
# 49  https://projectreporter.nih.gov/project_info_d...
# 50  https://projectreporter.nih.gov/project_info_d...
# 51                                                NaN
# 52  https://projectreporter.nih.gov/project_info_d...
# 53  https://projectreporter.nih.gov/project_info_d...
# 54  https://projectreporter.nih.gov/project_info_d...
# 55                                                NaN
# 56  https://projectreporter.nih.gov/project_info_d...
# 57  https://projectreporter.nih.gov/project_info_d...
# 58                                                NaN
# 59  https://projectreporter.nih.gov/project_info_d...

# %% [markdown]
# Annotate the nodes in the network according to the plan.

# %%
name_to_node_map = {}
for index, node in itcr_network.get_nodes():
    name_to_node_map[node.get_name()] = node
        
for index, row in node_data.iterrows():
    # Identify the corresponding node (skip if there is no such node)
    node = name_to_node_map.get(row['Title']) or name_to_node_map.get(row['Tool Acronym'])
    if node:
        
        # Add attributes to the node
        attributes = ["Category", "Tool URL", "Code Repo", "Project Info"]
        for att in attributes:
            itcr_network.set_node_attribute(node, att, row[att])
            
        # Set the "Tool Description" attribute of the node to the value of the "Body" column
        itcr_network.set_node_attribute(node, "Tool Description", row['Body'])
        
        # Set the node name to be the value of the "Title" column
        #node.set_name(row["Title"])
        
        # Set the "label" attribute to the value of the "Tool Acronym" when available, 
        # otherwise use the value of the "Title" column.
        acronym = row["Tool Acronym"]
        if not isinstance(acronym, str):
            acronym = None
        itcr_network.set_node_attribute(node, "label", acronym or row["Title"] or "no label")

# %% [markdown]
# Spot-check the network by printing out a sample of the nodes in the modified network

# %%
print(itcr_network.get_summary())

for id, node in itertools.islice(itcr_network.get_nodes(), 5):
    label = itcr_network.get_node_attribute(node, "label")
    tool = itcr_network.get_node_attribute(node, "Tool Description")
    print("%s: %s = %s" % (node.get_name(), label, tool))
# Out:
# Name: ITCR Connectivity Map
# Nodes: 36
# Edges: 81
# Node Attributes: 174
# Edge Attributes: 241
#
# TIES: TIES = TIES is a service based software system for acquiring, deidentifying, and processing clinical text reports using natural language processing, and also for querying, sharing and using this data to foster tissue and image based research, within and between institutions.
#
# TCPA: None = None
# HIVE (BioExpress): None = None
# TCIA: TCIA = TCIA is NCI’s repository for publicly shared cancer imaging data. TCIA collections include radiology and pathology images, clinical and clinical trial data, image derived annotations and quantitative features and a growing collection of related ‘omics data both from clinical and pre-clinical studies.
#
# OmniSearch: OmniSearch = OmniSearch is a semantic search software based upon the OMIT ontology. While OmniSearch is by its nature extensible, its initial focus is in human cancer research.

# %% [markdown]
# Upload the network to your NDEx account as a new network.
#
# If you started by loading an one of your networks (such as a clone of the example network), then you can *update* it instead, overwriting its content.
#
# In the commented line of below, the optional parameter *update_uuid* specifies the update behavior.

# %%
upload_message = my_network.upload(my_server, my_account, my_password)
# upload_message = my_network.upload(my_server, my_account, my_password, update_uuid=my_network_uuid)
print(upload_message)
