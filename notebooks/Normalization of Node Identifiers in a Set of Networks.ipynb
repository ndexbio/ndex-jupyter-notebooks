# %% [markdown]
# ## Normalization of Node Identifiers

# %% [markdown]
# This notebook demonstrates the normalization of the node identifiers in a set of networks. A set of example networks is cloned to your account and then each network is updated in turn. The normalization of the identifiers is performed using the mygene.info resource. The example networks are copies of selected NCI-PID networks, made in 2017.
#
# The tutorial demonstrates
# * Using Network Sets
# * Cloning networks
# * Using the mygene.info resource
# * Updating networks
# * Use of the @context aspect of a network
#
# #### Updates to Each Node:
#
# Identifiers are formatted using standard prefixes and the namespaces used are defined in the @context aspect of the network.
# * Node "name" = HGNC gene symbol (without prefix) i.e. **TP53**
# * Node "represents" = NCBI gene id, i.e. **ncbigene:7689**
# * The *former* node name is added to the values of the node attribute "alias" (i.e. the aliases)
# * The HGNC gene symbol *with* prefix is added the aliases
# * Uniprot identifiers in the aliases are updated to use the standard "uniprot" prefix

# %% [markdown]
# ### Import Packages

# %%
import ndex2
import json
import requests
from os.path import isfile, expanduser
import ndex2.client as nc
from datetime import datetime

# %% [markdown]
# ### NDEx Credentials
#
# Get the username and password to access your account from ndex_tutorial_config.json in your home directory. This file should have the following structure:
#
#     {
#       "username" : "<my_username>",
#       "password" : "<my_password>"
#     }

# %%
config_file = expanduser("~/ndex_tutorial_config.json")
my_username = None
my_password = None
my_server = 'public.ndexbio.org'
save_tutorial_networks_to_my_account = True

if(isfile(config_file)):
    file = open(config_file, "r")
    data = json.load(file)
    file.close()
    if data.get("password") and data.get("username"):
        my_username = data.get("username")
        my_password = data.get("password")
    else:
        print("Error: " + config_file + " does not define username and password")
else:
    print("Error: " + config_file + " was not found")

# %% [markdown]
# ### Get the Example Network Set by UUID

# %%
my_network_set = '71cde621-deb7-11e7-adc1-0ac135e8bacf'

ndex2_client = nc.Ndex2(host=my_server, username=my_username, password=my_password, debug=True)
set_response = ndex2_client.get_network_set(my_network_set)
uuids = set_response.get('networks')  # for one or more individually specified networks

print(uuids)
# Out:
# GET route: http://public.ndexbio.org/v2/networkset/71cde621-deb7-11e7-adc1-0ac135e8bacf
# status code: 200
# [u'bdc113d9-df7e-11e7-adc1-0ac135e8bacf', u'da171b21-df7e-11e7-adc1-0ac135e8bacf', u'd3887c8f-df7e-11e7-adc1-0ac135e8bacf', u'cdec2d3d-df7e-11e7-adc1-0ac135e8bacf', u'c7f3660b-df7e-11e7-adc1-0ac135e8bacf']

# %% [markdown]
# ### Functions to Access mygene.info and Update Nodes

# %%
def query_mygene_x(q, tax_id='9606', entrezonly=True):
    if entrezonly:
        r = requests.get('http://mygene.info/v3/query?q=' + q + '&species=' + tax_id + '&entrezonly=true')
    else:
        r = requests.get('http://mygene.info/v3/query?q=' + q + '&species=' + tax_id)
    result = r.json()
    hits = result.get("hits")
    if hits and len(hits) > 0:
        return hits[0]
    return False


def query_batch(query_string, tax_id='9606', scopes="symbol, entrezgene, alias, uniprot", fields="symbol, entrezgene, uniprot"):
    data = {'species': tax_id,
            'scopes': scopes,
            'fields': fields,
            'q': query_string}
    r = requests.post('http://mygene.info/v3/query', data)
    json = r.json()
    return json


def query_mygene(q):
    hits = query_batch(q)
    for hit in hits:
        symbol = hit.get('symbol')
        id = hit.get('entrezgene')
        if symbol and id:
            return (symbol, id)
    return None

# per node update method
def update_node(node, nicecx):
    print("\nnode %s" % node.get_name())
    original_node_name = node.get_name()
    aliases = nicecx.get_node_attribute(node, "alias")
    print("aliases: %s" % aliases)
    query_string = ''
    # if aliases:
    # aliases.push(name)
    # else:
    # aliases = [name]

    for alias in aliases:
        # assume uniprot
        id = alias.split(':')[-1]
        query_string += str(id) + ' '
    print(query_string)
    hits = query_batch(query_string)
    print(hits)
    
    alias_tmp = []
    for hit in hits:
        symbol = hit.get('symbol')
        id = hit.get('entrezgene')
        uniprot = hit.get('_id')
        
        if symbol and id:
            if len(alias_tmp) > 0:
                print(hits)
                # IF WE REACH THIS POINT WE ASSUME THIS
                # IS A PROTIEN FAMILY. RESET THE NODE 
                # BACK TO THE PROTIEN FAMILY NAME
                node.set_node_name(original_node_name)
                node.set_node_represents('')

                #raise Exception('Found Dup ' + symbol)
            else:
                node.set_node_name(symbol)
                node.set_node_represents('ncbigene:' + str(id))

            alias_tmp.append('hgnc.symbol:' + symbol)
            alias_tmp.append('ncbigene:' + str(id))

            if uniprot is not None:
                alias_tmp.append('uniprot:' + uniprot)
            else:
                raise Exception('uniprot not found ' + symbol)
        
    if len(alias_tmp) > 0:
        alias_tmp = list(set(alias_tmp))
        nicecx.set_node_attribute(node, "alias", alias_tmp)
    else:
        hit = query_mygene(node.get_name())
        if hit:
            succeed = True
            if len(hit) > 0 and hit[0] is not None:
                node.set_node_name('hgnc.symbol:' + hit[0])
            if len(hit) > 1 and hit[1] is not None:
                node.set_node_represents('ncbigene:' + str(hit[1]))
            print("hit: %s" % json.dumps(hit, indent=4))
        
    
    
    '''
    hit = query_mygene(node.get_name())
    if hit:
        succeed = True
        if (len(hit) > 0):
            node.set_node_name(hit[0])
        if (len(hit) > 1):
            node.set_node_represents('ncbigene:' + str(hit[1])
        print("hit: %s" % json.dumps(hit, indent=4))
    else:
        succeed = False
        for alias in aliases:
            # assume uniprot
            id = alias.split(':')[-1]
            hit = query_mygene(id)
            if hit:
                print("hit: %s" % json.dumps(hit, indent=4))
                succeed = True
                if(len(hit) > 0):
                    node.set_node_name(hit[0])
                if(len(hit) > 1):
                    node.set_node_represents('ncbigene:' + str(hit[1])

                break
        if not succeed:
            print("no gene hit for node %s " % node.get_name())
    '''

# %%
# TBD: create output network set
# HUGO example: hgnc.symbol:tp53 --> non-prefixed hugo symbol
# Entrez NCBI example: ncbigene:7157 --> represents
# Aliases with prefixes
# iteration over networks
count = 1

net_set_uuid = ndex2_client.create_networkset('Normalized Networks' + str(datetime.now()), 'Normalized Networks')
net_set_uuid = net_set_uuid.split('/')[-1]
print('Network set uuid:')
print(net_set_uuid)
add_these_networks = []

for network_uuid in uuids:
    # load network in NiceCX
    ncx = ndex2.create_nice_cx_from_server(server=my_server, uuid=network_uuid)
    context = [{'ncbigene': 'http://identifiers.org/ncbigene/', 
               'hgnc.symbol': 'http://identifiers.org/hgnc.symbol/',
              'uniprot': 'http://identifiers.org/uniprot/'}]
    ncx.set_context(context)
    for id, node in ncx.get_nodes():
        update_node(node, ncx)
    
    ncx.set_name('Normalized Nodes ' + str(count))
    count += 1
    if save_tutorial_networks_to_my_account:
        upload_message = ncx.upload_to(my_server, my_username, my_password)
        net_uuid = upload_message.split('/')[-1]
        print(net_uuid)
        add_these_networks.append(net_uuid)

ndex2_client.add_networks_to_networkset(net_set_uuid, add_these_networks)        

print('------------------------ DONE ------------------------')
#print(ncx.to_cx())
# Out:
# POST route: http://public.ndexbio.org/v2/networkset
# POST json: {"name": "Normalized Networks2017-12-14 14:21:56.436124", "description": "Normalized Networks"}
# status code: 201
# response text: http://public.ndexbio.org/v2/networkset/31d5b65d-e11d-11e7-adc1-0ac135e8bacf
# Network set uuid:
# 31d5b65d-e11d-11e7-adc1-0ac135e8bacf
#
# node GPC2
# aliases: [u'uniprot knowledgebase:A4D2A7', u'uniprot knowledgebase:Q8N158']
# A4D2A7 Q8N158
# [{u'query': u'A4D2A7', u'notfound': True}, {u'_score': 22.423883, u'symbol': u'GPC2', u'entrezgene': 221914, u'uniprot': {u'Swiss-Prot': u'Q8N158', u'TrEMBL': u'A0A0J9YXG7'}, u'query': u'Q8N158', u'_id': u'221914'}]
#
# node MK
# aliases: [u'uniprot knowledgebase:P21741', u'uniprot knowledgebase:Q2LEK4', u'uniprot knowledgebase:Q9UCC7']
# P21741 Q2LEK4 Q9UCC7
# [{u'_score': 22.422377, u'symbol': u'MDK', u'entrezgene': 4192, u'uniprot': {u'Swiss-Prot': u'P21741', u'TrEMBL': [u'E9PPJ5', u'C9JHA4', u'E9PLM6', u'A0A087WXB6']}, u'query': u'P21741', u'_id': u'4192'}, {u'query': u'Q2LEK4', u'notfound': True}, {u'query': u'Q9UCC7', u'notfound': True}]
# 327d19ee-e11d-11e7-adc1-0ac135e8bacf
#
# node FKB1A
# aliases: [u'uniprot knowledgebase:D3DVW6', u'uniprot knowledgebase:P20071', u'uniprot knowledgebase:P62942', u'uniprot knowledgebase:Q4VC47', u'uniprot knowledgebase:Q6FGD9', u'uniprot knowledgebase:Q6LEU3', u'uniprot knowledgebase:Q9H103', u'uniprot knowledgebase:Q9H566']
# D3DVW6 P20071 P62942 Q4VC47 Q6FGD9 Q6LEU3 Q9H103 Q9H566
# [{u'query': u'D3DVW6', u'notfound': True}, {u'query': u'P20071', u'notfound': True}, {u'_score': 22.42439, u'symbol': u'FKBP1A', u'entrezgene': 2280, u'uniprot': {u'Swiss-Prot': u'P62942', u'TrEMBL': [u'Q0VDC6', u'A0A087WTS4', u'Q5W0X3', u'Q1JUQ3', u'Q1JUQ5', u'A0A087WZM5']}, u'query': u'P62942', u'_id': u'2280'}, {u'query': u'Q4VC47', u'notfound': True}, {u'query': u'Q6FGD9', u'notfound': True}, {u'query': u'Q6LEU3', u'notfound': True}, {u'query': u'Q9H103', u'notfound': True}, {u'query': u'Q9H566', u'notfound': True}]
#
# node AMHR2
# aliases: [u'uniprot knowledgebase:A0AVE1', u'uniprot knowledgebase:B9EGB7', u'uniprot knowledgebase:E9PGD2', u'uniprot knowledgebase:F8W1D2', u'uniprot knowledgebase:Q13762', u'uniprot knowledgebase:Q16671', u'uniprot knowledgebase:Q647K2']
# A0AVE1 B9EGB7 E9PGD2 F8W1D2 Q13762 Q16671 Q647K2
# [{u'notfound': True, u'query': u'A0AVE1'}, {u'notfound': True, u'query': u'B9EGB7'}, {u'notfound': True, u'query': u'E9PGD2'}, {u'notfound': True, u'query': u'F8W1D2'}, {u'notfound': True, u'query': u'Q13762'}, {u'_score': 20.416824, u'symbol': u'AMHR2', u'entrezgene': 269, u'uniprot': {u'Swiss-Prot': u'Q16671', u'TrEMBL': u'H3BPI9'}, u'query': u'Q16671', u'_id': u'269'}, {u'notfound': True, u'query': u'Q647K2'}]
#
# node SMAD9
# aliases: [u'uniprot knowledgebase:A2A2Y6', u'uniprot knowledgebase:O14989', u'uniprot knowledgebase:O15198', u'uniprot knowledgebase:Q5TBA1']
# A2A2Y6 O14989 O15198 Q5TBA1
# [{u'notfound': True, u'query': u'A2A2Y6'}, {u'notfound': True, u'query': u'O14989'}, {u'_score': 21.24041, u'symbol': u'SMAD9', u'entrezgene': 4093, u'uniprot': {u'Swiss-Prot': u'O15198', u'TrEMBL': u'A0A024RDR3'}, u'query': u'O15198', u'_id': u'4093'}, {u'notfound': True, u'query': u'Q5TBA1'}]
#
# node BMPR2
# aliases: [u'uniprot knowledgebase:Q13161', u'uniprot knowledgebase:Q13873', u'uniprot knowledgebase:Q16569', u'uniprot knowledgebase:Q4ZG08', u'uniprot knowledgebase:Q53SA5', u'uniprot knowledgebase:Q585T8']
# Q13161 Q13873 Q16569 Q4ZG08 Q53SA5 Q585T8
# [{u'notfound': True, u'query': u'Q13161'}, {u'_score': 20.413885, u'symbol': u'BMPR2', u'entrezgene': 659, u'uniprot': {u'Swiss-Prot': u'Q13873', u'TrEMBL': u'A0A1W2PPB5'}, u'query': u'Q13873', u'_id': u'659'}, {u'notfound': True, u'query': u'Q16569'}, {u'notfound': True, u'query': u'Q4ZG08'}, {u'notfound': True, u'query': u'Q53SA5'}, {u'notfound': True, u'query': u'Q585T8'}]
#
# node ACVR1
# aliases: [u'uniprot knowledgebase:Q04771']
# Q04771
# [{u'_score': 19.792055, u'symbol': u'ACVR1', u'entrezgene': 90, u'uniprot': {u'Swiss-Prot': u'Q04771', u'TrEMBL': [u'C9J1R3', u'D3DPA4', u'C9JHJ7', u'F5GY91', u'C9JW28', u'A0A1B0GXA9']}, u'query': u'Q04771', u'_id': u'90'}]
#
# node TLX2
# aliases: [u'uniprot knowledgebase:O43763', u'uniprot knowledgebase:Q9UD56', u'uniprot knowledgebase:Q9UQ48']
# O43763 Q9UD56 Q9UQ48
# [{u'_score': 21.240463, u'symbol': u'TLX2', u'entrezgene': 3196, u'uniprot': {u'Swiss-Prot': u'O43763', u'TrEMBL': u'F1T0F2'}, u'query': u'O43763', u'_id': u'3196'}, {u'query': u'Q9UD56', u'notfound': True}, {u'query': u'Q9UQ48', u'notfound': True}]
#
# node BMP7
# aliases: [u'uniprot knowledgebase:P18075', u'uniprot knowledgebase:Q9H512', u'uniprot knowledgebase:Q9NTQ7']
# P18075 Q9H512 Q9NTQ7
# [{u'_score': 20.414183, u'symbol': u'BMP7', u'entrezgene': 655, u'uniprot': {u'Swiss-Prot': u'P18075', u'TrEMBL': [u'H0Y4B5', u'A8K571', u'B1AL00', u'B1AKZ9']}, u'query': u'P18075', u'_id': u'655'}, {u'notfound': True, u'query': u'Q9H512'}, {u'notfound': True, u'query': u'Q9NTQ7'}]
#
# node SMAD5
# aliases: [u'uniprot knowledgebase:O14688', u'uniprot knowledgebase:Q15798', u'uniprot knowledgebase:Q99717', u'uniprot knowledgebase:Q9UQA1']
# O14688 Q15798 Q99717 Q9UQA1
# [{u'query': u'O14688', u'notfound': True}, {u'query': u'Q15798', u'notfound': True}, {u'_score': 20.416824, u'symbol': u'SMAD5', u'entrezgene': 4090, u'uniprot': {u'Swiss-Prot': u'Q99717', u'TrEMBL': [u'D6RIZ9', u'Q68DB7', u'H0YAK7', u'D6R9D4', u'D6RBB4', u'H0YAM3']}, u'query': u'Q99717', u'_id': u'4090'}, {u'query': u'Q9UQA1', u'notfound': True}]
#
# node SMAD1
# aliases: [u'uniprot knowledgebase:A8KAJ0', u'uniprot knowledgebase:D3DNZ9', u'uniprot knowledgebase:Q15797', u'uniprot knowledgebase:Q16636', u'uniprot knowledgebase:Q9UFT8']
# A8KAJ0 D3DNZ9 Q15797 Q16636 Q9UFT8
# [{u'query': u'A8KAJ0', u'notfound': True}, {u'query': u'D3DNZ9', u'notfound': True}, {u'_score': 20.414091, u'symbol': u'SMAD1', u'entrezgene': 4086, u'uniprot': {u'Swiss-Prot': u'Q15797', u'TrEMBL': [u'D6REQ3', u'D6RBH9', u'D6RAY1', u'D6RD62', u'D6RDN7', u'A0A1D5RMR4']}, u'query': u'Q15797', u'_id': u'4086'}, {u'query': u'Q16636', u'notfound': True}, {u'query': u'Q9UFT8', u'notfound': True}]
#
# node SMAD4
# aliases: [u'uniprot knowledgebase:A8K405', u'uniprot knowledgebase:Q13485']
# A8K405 Q13485
# [{u'notfound': True, u'query': u'A8K405'}, {u'_score': 19.283913, u'symbol': u'SMAD4', u'entrezgene': 4089, u'uniprot': {u'Swiss-Prot': u'Q13485', u'TrEMBL': [u'K7EL18', u'A0A024R274', u'K7EL15', u'K7ENG1', u'K7ELK2', u'A0A087WUF3', u'K7ENG8', u'K7ES96', u'K7EIU8', u'K7EIJ2']}, u'query': u'Q13485', u'_id': u'4089'}]
#
# node MIS
# aliases: [u'uniprot knowledgebase:O75246', u'uniprot knowledgebase:P03971', u'uniprot knowledgebase:Q6GTN3']
# O75246 P03971 Q6GTN3
# [{u'notfound': True, u'query': u'O75246'}, {u'_score': 20.419746, u'symbol': u'AMH', u'entrezgene': 268, u'uniprot': {u'Swiss-Prot': u'P03971'}, u'query': u'P03971', u'_id': u'268'}, {u'notfound': True, u'query': u'Q6GTN3'}]
# 33c26b31-e11d-11e7-adc1-0ac135e8bacf
#
# node H33
# aliases: [u'uniprot knowledgebase:P06351', u'uniprot knowledgebase:P33155', u'uniprot knowledgebase:P84243', u'uniprot knowledgebase:Q5VV55', u'uniprot knowledgebase:Q5VV56', u'uniprot knowledgebase:Q66I33', u'uniprot knowledgebase:Q9V3W4']
# P06351 P33155 P84243 Q5VV55 Q5VV56 Q66I33 Q9V3W4
# [{u'notfound': True, u'query': u'P06351'}, {u'notfound': True, u'query': u'P33155'}, {u'_score': 20.414827, u'symbol': u'H3F3B', u'entrezgene': 3021, u'uniprot': {u'Swiss-Prot': u'P84243', u'TrEMBL': [u'B4DEB1', u'B2R4P9', u'K7ES00', u'K7EK07', u'K7EMV3', u'K7EP01']}, u'query': u'P84243', u'_id': u'3021'}, {u'_score': 20.414185, u'symbol': u'H3F3A', u'entrezgene': 3020, u'uniprot': {u'Swiss-Prot': u'P84243', u'TrEMBL': [u'B4DEB1', u'B2R4P9', u'K7ES00', u'K7EK07', u'K7EMV3', u'K7EP01']}, u'query': u'P84243', u'_id': u'3020'}, {u'notfound': True, u'query': u'Q5VV55'}, {u'notfound': True, u'query': u'Q5VV56'}, {u'notfound': True, u'query': u'Q66I33'}, {u'notfound': True, u'query': u'Q9V3W4'}]
# [{u'notfound': True, u'query': u'P06351'}, {u'notfound': True, u'query': u'P33155'}, {u'_score': 20.414827, u'symbol': u'H3F3B', u'entrezgene': 3021, u'uniprot': {u'Swiss-Prot': u'P84243', u'TrEMBL': [u'B4DEB1', u'B2R4P9', u'K7ES00', u'K7EK07', u'K7EMV3', u'K7EP01']}, u'query': u'P84243', u'_id': u'3021'}, {u'_score': 20.414185, u'symbol': u'H3F3A', u'entrezgene': 3020, u'uniprot': {u'Swiss-Prot': u'P84243', u'TrEMBL': [u'B4DEB1', u'B2R4P9', u'K7ES00', u'K7EK07', u'K7EMV3', u'K7EP01']}, u'query': u'P84243', u'_id': u'3020'}, {u'notfound': True, u'query': u'Q5VV55'}, {u'notfound': True, u'query': u'Q5VV56'}, {u'notfound': True, u'query': u'Q66I33'}, {u'notfound': True, u'query': u'Q9V3W4'}]
#
# node AURKC
# aliases: [u'uniprot knowledgebase:O60681', u'uniprot knowledgebase:O75442', u'uniprot knowledgebase:Q6AZY8', u'uniprot knowledgebase:Q6DLZ0', u'uniprot knowledgebase:Q9UPK5', u'uniprot knowledgebase:Q9UQB9']
# O60681 O75442 Q6AZY8 Q6DLZ0 Q9UPK5 Q9UQB9
# [{u'query': u'O60681', u'notfound': True}, {u'query': u'O75442', u'notfound': True}, {u'query': u'Q6AZY8', u'notfound': True}, {u'query': u'Q6DLZ0', u'notfound': True}, {u'query': u'Q9UPK5', u'notfound': True}, {u'_score': 22.426224, u'symbol': u'AURKC', u'entrezgene': 6795, u'uniprot': {u'Swiss-Prot': u'Q9UQB9', u'TrEMBL': [u'B4DXA6', u'Q5Y191', u'M0QYK8', u'A0A0A0MSY3', u'M0QX60']}, u'query': u'Q9UQB9', u'_id': u'6795'}]
#
# node INCE
# aliases: [u'uniprot knowledgebase:A8MQD2', u'uniprot knowledgebase:Q5Y192', u'uniprot knowledgebase:Q9NQS7']
# A8MQD2 Q5Y192 Q9NQS7
# [{u'notfound': True, u'query': u'A8MQD2'}, {u'notfound': True, u'query': u'Q5Y192'}, {u'_score': 22.423883, u'symbol': u'INCENP', u'entrezgene': 3619, u'uniprot': {u'Swiss-Prot': u'Q9NQS7', u'TrEMBL': u'E9PM67'}, u'query': u'Q9NQS7', u'_id': u'3619'}]
#
# node AURKB
# aliases: [u'uniprot knowledgebase:B4DNM4', u'uniprot knowledgebase:C7G533', u'uniprot knowledgebase:C7G534', u'uniprot knowledgebase:C7G535', u'uniprot knowledgebase:D3DTR4', u'uniprot knowledgebase:J9JID1', u'uniprot knowledgebase:O14630', u'uniprot knowledgebase:O60446', u'uniprot knowledgebase:O95083', u'uniprot knowledgebase:Q96DV5', u'uniprot knowledgebase:Q96GD4', u'uniprot knowledgebase:Q9UQ46']
# B4DNM4 C7G533 C7G534 C7G535 D3DTR4 J9JID1 O14630 O60446 O95083 Q96DV5 Q96GD4 Q9UQ46
# [{u'query': u'B4DNM4', u'notfound': True}, {u'query': u'C7G533', u'notfound': True}, {u'query': u'C7G534', u'notfound': True}, {u'query': u'C7G535', u'notfound': True}, {u'query': u'D3DTR4', u'notfound': True}, {u'query': u'J9JID1', u'notfound': True}, {u'query': u'O14630', u'notfound': True}, {u'query': u'O60446', u'notfound': True}, {u'query': u'O95083', u'notfound': True}, {u'query': u'Q96DV5', u'notfound': True}, {u'_score': 20.414827, u'symbol': u'AURKB', u'entrezgene': 9212, u'uniprot': {u'Swiss-Prot': u'Q96GD4', u'TrEMBL': [u'J3KTD6', u'J3QR41', u'J3KRJ2', u'J3KT86', u'J3KRF8', u'J3QLN8']}, u'query': u'Q96GD4', u'_id': u'9212'}, {u'query': u'Q9UQ46', u'notfound': True}]
# 349ec174-e11d-11e7-adc1-0ac135e8bacf
#
# node PDE3B
# aliases: [u'uniprot knowledgebase:B7ZM37', u'uniprot knowledgebase:O00639', u'uniprot knowledgebase:Q13370', u'uniprot knowledgebase:Q14408', u'uniprot knowledgebase:Q6SEI4']
# B7ZM37 O00639 Q13370 Q14408 Q6SEI4
# [{u'query': u'B7ZM37', u'notfound': True}, {u'query': u'O00639', u'notfound': True}, {u'_score': 21.236609, u'symbol': u'PDE3B', u'entrezgene': 5140, u'uniprot': {u'Swiss-Prot': u'Q13370', u'TrEMBL': u'A7E2E5'}, u'query': u'Q13370', u'_id': u'5140'}, {u'query': u'Q14408', u'notfound': True}, {u'query': u'Q6SEI4', u'notfound': True}]
#
# node MK01
# aliases: [u'uniprot knowledgebase:A8CZ64', u'uniprot knowledgebase:P28482']
# A8CZ64 P28482
# [{u'query': u'A8CZ64', u'notfound': True}, {u'_score': 19.283194, u'symbol': u'MAPK1', u'entrezgene': 5594, u'uniprot': {u'Swiss-Prot': u'P28482', u'TrEMBL': [u'Q499G7', u'Q1HBJ4']}, u'query': u'P28482', u'_id': u'5594'}]
#
# node PK3CG
# aliases: [u'uniprot knowledgebase:A4D0Q6', u'uniprot knowledgebase:P48736', u'uniprot knowledgebase:Q8IV23', u'uniprot knowledgebase:Q9BZC8']
# A4D0Q6 P48736 Q8IV23 Q9BZC8
# [{u'notfound': True, u'query': u'A4D0Q6'}, {u'_score': 21.235966, u'symbol': u'PIK3CG', u'entrezgene': 5294, u'uniprot': {u'Swiss-Prot': u'P48736', u'TrEMBL': [u'A8K9G9', u'A0A024R720', u'E9PDN7']}, u'query': u'P48736', u'_id': u'5294'}, {u'notfound': True, u'query': u'Q8IV23'}, {u'notfound': True, u'query': u'Q9BZC8'}]
#
# node PI3R6
# aliases: [u'uniprot knowledgebase:Q5UE93', u'uniprot knowledgebase:Q658R3']
# Q5UE93 Q658R3
# [{u'_score': 22.419865, u'symbol': u'PIK3R6', u'entrezgene': 146850, u'uniprot': {u'Swiss-Prot': u'Q5UE93', u'TrEMBL': [u'A0A087X1F3', u'B3KRK9']}, u'query': u'Q5UE93', u'_id': u'146850'}, {u'query': u'Q658R3', u'notfound': True}]
#
# node MP2K1
# aliases: [u'uniprot knowledgebase:Q02750']
# Q02750
# [{u'_score': 21.235697, u'symbol': u'MAP2K1', u'entrezgene': 5604, u'uniprot': {u'Swiss-Prot': u'Q02750', u'TrEMBL': [u'B4DFY5', u'A4QPA9', u'H3BRW9']}, u'query': u'Q02750', u'_id': u'5604'}]
# 358acf27-e11d-11e7-adc1-0ac135e8bacf
#
# node FYN
# aliases: [u'uniprot knowledgebase:B5BU57', u'uniprot knowledgebase:E1P557', u'uniprot knowledgebase:H0UI48', u'uniprot knowledgebase:P06241', u'uniprot knowledgebase:Q16248', u'uniprot knowledgebase:Q5R3A6', u'uniprot knowledgebase:Q5R3A7', u'uniprot knowledgebase:Q8N5D7']
# B5BU57 E1P557 H0UI48 P06241 Q16248 Q5R3A6 Q5R3A7 Q8N5D7
# [{u'notfound': True, u'query': u'B5BU57'}, {u'notfound': True, u'query': u'E1P557'}, {u'notfound': True, u'query': u'H0UI48'}, {u'_score': 19.793476, u'symbol': u'FYN', u'entrezgene': 2534, u'uniprot': {u'Swiss-Prot': u'P06241', u'TrEMBL': [u'E5RH71', u'E5RHX7', u'E5RFS5', u'E5RFM6', u'E5RGT0', u'E5RHF7', u'E5RFM4', u'E5RK23', u'E5RI25', u'E5RGM6', u'E5RIX5', u'E5RFM0', u'E5RJX7']}, u'query': u'P06241', u'_id': u'2534'}, {u'notfound': True, u'query': u'Q16248'}, {u'notfound': True, u'query': u'Q5R3A6'}, {u'notfound': True, u'query': u'Q5R3A7'}, {u'notfound': True, u'query': u'Q8N5D7'}]
#
# node EPHA5
# aliases: [u'uniprot knowledgebase:P54756', u'uniprot knowledgebase:Q7Z3F2']
# P54756 Q7Z3F2
# [{u'_score': 22.424543, u'symbol': u'EPHA5', u'entrezgene': 2044, u'uniprot': {u'Swiss-Prot': u'P54756', u'TrEMBL': [u'B7ZKJ3', u'B7ZKW7', u'Q59FT4', u'F8VP57', u'F8W9W0']}, u'query': u'P54756', u'_id': u'2044'}, {u'query': u'Q7Z3F2', u'notfound': True}]
#
# node EFNA5
# aliases: [u'uniprot knowledgebase:P52803']
# P52803
# [{u'_score': 22.425896, u'symbol': u'EFNA5', u'entrezgene': 1946, u'uniprot': {u'Swiss-Prot': u'P52803', u'TrEMBL': [u'A0A087X240', u'D6RDV5']}, u'query': u'P52803', u'_id': u'1946'}]
# 364d0dba-e11d-11e7-adc1-0ac135e8bacf
# POST route: http://public.ndexbio.org/v2/networkset/31d5b65d-e11d-11e7-adc1-0ac135e8bacf/members
# POST json: ["327d19ee-e11d-11e7-adc1-0ac135e8bacf", "33c26b31-e11d-11e7-adc1-0ac135e8bacf", "349ec174-e11d-11e7-adc1-0ac135e8bacf", "358acf27-e11d-11e7-adc1-0ac135e8bacf", "364d0dba-e11d-11e7-adc1-0ac135e8bacf"]
# status code: 201
# response text: http://public.ndexbio.org/v2/networkset/31d5b65d-e11d-11e7-adc1-0ac135e8bacf/members
# ------------------------ DONE ------------------------
